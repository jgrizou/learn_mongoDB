# %%
# When you put a bang (exclamation point) at the beginning of a line, everything that follows 
# will be executed in your terminal.
#
# In this case, we're using pip to install the dateparser module.
# This module will help us parse datetimes from strings.
# !pip install dateparser

# %%
import pymongo
import pprint
import dateparser

# %%
# Replace XXXX with your connection URI from the Atlas UI
course_cluster_uri = 'mongodb://analytics:analytics-password@mflix-shard-00-00-niw9w.mongodb.net:27017,mflix-shard-00-01-niw9w.mongodb.net:27017,mflix-shard-00-02-niw9w.mongodb.net:27017/test?ssl=true&replicaSet=mflix-shard-0&authSource=admin&retryWrites=true'

# %%
course_client = pymongo.MongoClient(course_cluster_uri)
movies = course_client['mflix']['movies']

# %%
query = {"comments":{"$exists": True}}
projection = {"comments": 1}

movie = movies.find_one(query, projection)

pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd4135'),
#  'comments': [{'_id': '573a1390f29313caabcd4135-Richard Davis-593338270.0',
#                'date': datetime.datetime(1988, 10, 20, 4, 11, 10),
#                'email': 'richard_davis@fakegmail.com',
#                'movie_id': ObjectId('573a1390f29313caabcd4135'),
#                'name': 'Richard Davis',
#                'text': 'Veniam repudiandae neque ipsam temporibus corporis et. '
#                        'Vitae sed incidunt quaerat odio hic debitis odit. '
#                        'Ullam perspiciatis suscipit fugiat suscipit.'}]}

# %%
query = {"comments.name": "Samwell Tarly"}

movie = movies.find_one(query, projection)

pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1390f29313caabcd54ed'),
#  'comments': [{'_id': '573a1390f29313caabcd54ed-Tywin Lannister-1337423784.0',
#                'date': datetime.datetime(2012, 5, 19, 6, 36, 24),
#                'email': 'charles_dance@gameofthron.es',
#                'movie_id': ObjectId('573a1390f29313caabcd54ed'),
#                'name': 'Tywin Lannister',
#                'text': 'Sapiente tempora non vero officiis assumenda eligendi. '
#                        'Consequatur iusto qui in possimus animi modi. Id '
#                        'commodi non ipsam. Ad officia nisi dolor voluptatibus '
#                        'numquam porro ducimus.'},
#               {'_id': '573a1390f29313caabcd54ed-Samwell Tarly-572777793.0',
#                'date': datetime.datetime(1988, 2, 25, 3, 56, 33),
#                'email': 'john_bradley-west@gameofthron.es',
#                'movie_id': ObjectId('573a1390f29313caabcd54ed'),
#                'name': 'Samwell Tarly',
#                'text': 'Natus enim voluptate dolore. Quo porro ipsum enim. Est '
#                        'totam sapiente nam vero.'},
#               {'_id': '573a1390f29313caabcd54ed-Emily Ellis-557039795.0',
#                'date': datetime.datetime(1987, 8, 27, 1, 16, 35),
#                'email': 'emily_ellis@fakegmail.com',
#                'movie_id': ObjectId('573a1390f29313caabcd54ed'),
#                'name': 'Emily Ellis',
#                'text': 'Facere magnam quibusdam impedit sed expedita neque. '
#                        'Eos rem minus blanditiis non id quibusdam quia. Nam '
#                        'harum nam iure voluptatem doloribus quis ut incidunt. '
#                        'Maxime accusamus veniam ut quas ipsam.'}]}

# %%
query = {
  "comments.name": "Samwell Tarly",
  "comments.date": {
    "$lt": dateparser.parse("1995-01-01")
  }
}

movie = movies.find(query, projection)

pprint.pprint(list(movie))
# Out:
# [{'_id': ObjectId('573a1390f29313caabcd54ed'),
#   'comments': [{'_id': '573a1390f29313caabcd54ed-Tywin Lannister-1337423784.0',
#                 'date': datetime.datetime(2012, 5, 19, 6, 36, 24),
#                 'email': 'charles_dance@gameofthron.es',
#                 'movie_id': ObjectId('573a1390f29313caabcd54ed'),
#                 'name': 'Tywin Lannister',
#                 'text': 'Sapiente tempora non vero officiis assumenda '
#                         'eligendi. Consequatur iusto qui in possimus animi '
#                         'modi. Id commodi non ipsam. Ad officia nisi dolor '
#                         'voluptatibus numquam porro ducimus.'},
#                {'_id': '573a1390f29313caabcd54ed-Samwell Tarly-572777793.0',
#                 'date': datetime.datetime(1988, 2, 25, 3, 56, 33),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1390f29313caabcd54ed'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Natus enim voluptate dolore. Quo porro ipsum enim. '
#                         'Est totam sapiente nam vero.'},
#                {'_id': '573a1390f29313caabcd54ed-Emily Ellis-557039795.0',
#                 'date': datetime.datetime(1987, 8, 27, 1, 16, 35),
#                 'email': 'emily_ellis@fakegmail.com',
#                 'movie_id': ObjectId('573a1390f29313caabcd54ed'),
#                 'name': 'Emily Ellis',
#                 'text': 'Facere magnam quibusdam impedit sed expedita neque. '
#                         'Eos rem minus blanditiis non id quibusdam quia. Nam '
#                         'harum nam iure voluptatem doloribus quis ut incidunt. '
#                         'Maxime accusamus veniam ut quas ipsam.'}]},
#  {'_id': ObjectId('573a1391f29313caabcd8f9a'),
#   'comments': [{'_id': '573a1391f29313caabcd8f9a-Kelsey Smith-1367246967.0',
#                 'date': datetime.datetime(2013, 4, 29, 10, 49, 27),
#                 'email': 'kelsey_smith@fakegmail.com',
#                 'movie_id': ObjectId('573a1391f29313caabcd8f9a'),
#                 'name': 'Kelsey Smith',
#                 'text': 'Modi minima necessitatibus beatae deleniti suscipit '
#                         'rerum. Nulla blanditiis officiis sed at vel repellat '
#                         'sequi. Fuga ipsam molestiae architecto nulla qui '
#                         'aut.'},
#                {'_id': '573a1391f29313caabcd8f9a-Samwell Tarly-961928262.0',
#                 'date': datetime.datetime(2000, 6, 25, 6, 17, 42),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1391f29313caabcd8f9a'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Incidunt placeat rem molestiae optio laborum. At '
#                         'necessitatibus impedit ratione iure voluptates nobis '
#                         'explicabo. In quae pariatur repellat nobis. '
#                         'Exercitationem ullam eveniet non.'},
#                {'_id': '573a1391f29313caabcd8f9a-Kristen Schmidt-489082166.0',
#                 'date': datetime.datetime(1985, 7, 1, 12, 9, 26),
#                 'email': 'kristen_schmidt@fakegmail.com',
#                 'movie_id': ObjectId('573a1391f29313caabcd8f9a'),
#                 'name': 'Kristen Schmidt',
#                 'text': 'Sit quam eos at eligendi quis ex ipsam. Ab alias cum '
#                         'ex ipsam. Reprehenderit harum incidunt iusto veniam '
#                         'omnis est.'}]},
#  {'_id': ObjectId('573a1391f29313caabcd91dc'),
#   'comments': [{'_id': '573a1391f29313caabcd91dc-Patricia Good-1254693496.0',
#                 'date': datetime.datetime(2009, 10, 4, 17, 58, 16),
#                 'email': 'patricia_good@fakegmail.com',
#                 'movie_id': ObjectId('573a1391f29313caabcd91dc'),
#                 'name': 'Patricia Good',
#                 'text': 'Laudantium sed amet sed sint blanditiis facilis. '
#                         'Alias omnis sequi pariatur voluptates repudiandae '
#                         'dicta. Dignissimos natus corporis voluptatum impedit '
#                         'commodi.'},
#                {'_id': '573a1391f29313caabcd91dc-Samwell Tarly-766239623.0',
#                 'date': datetime.datetime(1994, 4, 13, 8, 20, 23),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1391f29313caabcd91dc'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Alias qui voluptate facilis id. Odit ducimus nulla '
#                         'excepturi. Veniam quam voluptatem recusandae vitae '
#                         'perspiciatis. Inventore ad laborum amet magnam '
#                         'voluptatum.'},
#                {'_id': '573a1391f29313caabcd91dc-Megan Richards-345323060.0',
#                 'date': datetime.datetime(1980, 12, 10, 14, 4, 20),
#                 'email': 'megan_richards@fakegmail.com',
#                 'movie_id': ObjectId('573a1391f29313caabcd91dc'),
#                 'name': 'Megan Richards',
#                 'text': 'Nisi rerum quasi nemo eaque incidunt optio nisi. '
#                         'Eveniet delectus ex iure vero cum quae nisi. Numquam '
#                         'repudiandae similique doloremque.'}]},
#  {'_id': ObjectId('573a1391f29313caabcd9336'),
#   'comments': [{'_id': '573a1391f29313caabcd9336-Samwell Tarly-117671803.0',
#                 'date': datetime.datetime(1973, 9, 23, 18, 36, 43),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1391f29313caabcd9336'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Aperiam doloribus sunt quaerat. Suscipit blanditiis '
#                         'cumque fuga commodi sint. A quae cum nihil iusto '
#                         'provident adipisci deserunt quibusdam.'}]},
#  {'_id': ObjectId('573a1392f29313caabcd9801'),
#   'comments': [{'_id': '573a1392f29313caabcd9801-Samwell Tarly-1329688206.0',
#                 'date': datetime.datetime(2012, 2, 19, 16, 50, 6),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcd9801'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Optio delectus in officia ipsam deleniti. Nam '
#                         'architecto esse ut debitis consequatur eligendi. '
#                         'Voluptate qui rerum beatae dignissimos tenetur ipsa '
#                         'iusto.'},
#                {'_id': '573a1392f29313caabcd9801-Brenda Martin-149207933.0',
#                 'date': datetime.datetime(1974, 9, 23, 18, 38, 53),
#                 'email': 'brenda_martin@fakegmail.com',
#                 'movie_id': ObjectId('573a1392f29313caabcd9801'),
#                 'name': 'Brenda Martin',
#                 'text': 'Similique laboriosam minima atque. Maiores at hic est '
#                         'ullam. Tempora culpa repellendus ab dolorum possimus '
#                         'doloremque.'}]},
#  {'_id': ObjectId('573a1392f29313caabcd9997'),
#   'comments': [{'_id': '573a1392f29313caabcd9997-Samwell Tarly-1152449914.0',
#                 'date': datetime.datetime(2006, 7, 9, 8, 58, 34),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcd9997'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Autem doloribus eveniet totam rem fugit eaque a. '
#                         'Exercitationem commodi cumque aperiam autem '
#                         'accusamus. Suscipit vel distinctio unde dolorum odio '
#                         'quibusdam.'},
#                {'_id': '573a1392f29313caabcd9997-Viserys Targaryen-66445262.0',
#                 'date': datetime.datetime(1972, 2, 8, 20, 1, 2),
#                 'email': 'harry_lloyd@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcd9997'),
#                 'name': 'Viserys Targaryen',
#                 'text': 'Nam optio dolores molestiae deleniti ea provident. '
#                         'Commodi ex nam aliquam ipsum nam dolore iusto. Sit a '
#                         'quam quia aspernatur perferendis sunt aliquam.'}]},
#  {'_id': ObjectId('573a1392f29313caabcd9cc7'),
#   'comments': [{'_id': '573a1392f29313caabcd9cc7-Samwell Tarly-436827450.0',
#                 'date': datetime.datetime(1983, 11, 4, 15, 57, 30),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcd9cc7'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Deserunt possimus laudantium soluta hic esse. Fuga '
#                         'dolor perferendis aliquam molestiae vitae pariatur. '
#                         'Aut vel delectus saepe et. Dicta eos commodi atque '
#                         'quae totam laborum nemo.'}]},
#  {'_id': ObjectId('573a1392f29313caabcd9d00'),
#   'comments': [{'_id': '573a1392f29313caabcd9d00-Samwell Tarly-1472893894.0',
#                 'date': datetime.datetime(2016, 9, 3, 5, 11, 34),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcd9d00'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Error illum reprehenderit saepe ab natus. Itaque '
#                         'minus accusantium ex corrupti.'},
#                {'_id': '573a1392f29313caabcd9d00-Talisa Maegyr-1243500646.0',
#                 'date': datetime.datetime(2009, 5, 28, 4, 50, 46),
#                 'email': 'oona_chaplin@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcd9d00'),
#                 'name': 'Talisa Maegyr',
#                 'text': 'Doloremque accusantium asperiores mollitia occaecati. '
#                         'Dolorem voluptates vitae delectus tempore neque '
#                         'porro. Unde deleniti hic suscipit.'},
#                {'_id': '573a1392f29313caabcd9d00-Tyrion Lannister-633053322.0',
#                 'date': datetime.datetime(1990, 1, 22, 19, 8, 42),
#                 'email': 'peter_dinklage@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcd9d00'),
#                 'name': 'Tyrion Lannister',
#                 'text': 'Veritatis libero sequi consectetur fugiat '
#                         'necessitatibus. Voluptas nemo nam sapiente beatae '
#                         'reiciendis sunt. Possimus impedit quis minus aliquid '
#                         'placeat.'}]},
#  {'_id': ObjectId('573a1392f29313caabcda1d8'),
#   'comments': [{'_id': '573a1392f29313caabcda1d8-Tyrion Lannister-593954204.0',
#                 'date': datetime.datetime(1988, 10, 27, 7, 16, 44),
#                 'email': 'peter_dinklage@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcda1d8'),
#                 'name': 'Tyrion Lannister',
#                 'text': 'Facilis labore dolor nulla eveniet temporibus. Illo '
#                         'eaque sed illo veniam qui placeat. Quidem laborum '
#                         'labore quas optio nostrum aliquam. Architecto '
#                         'voluptates incidunt error id officia.'},
#                {'_id': '573a1392f29313caabcda1d8-Samwell Tarly-224271905.0',
#                 'date': datetime.datetime(1977, 2, 8, 12, 45, 5),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcda1d8'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Sint sint deleniti eveniet similique repudiandae quis '
#                         'reprehenderit possimus. Velit recusandae distinctio '
#                         'vel illum amet. Sed rerum eaque animi eos eveniet '
#                         'nesciunt aspernatur.'}]},
#  {'_id': ObjectId('573a1392f29313caabcdade0'),
#   'comments': [{'_id': '573a1392f29313caabcdade0-Samwell Tarly-851298054.0',
#                 'date': datetime.datetime(1996, 12, 22, 18, 40, 54),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcdade0'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Magnam aperiam aut praesentium totam. Sint aliquid '
#                         'error minus. Possimus dicta exercitationem quis '
#                         'quidem ipsum id.'},
#                {'_id': '573a1392f29313caabcdade0-Megan Richards-375877924.0',
#                 'date': datetime.datetime(1981, 11, 29, 5, 32, 4),
#                 'email': 'megan_richards@fakegmail.com',
#                 'movie_id': ObjectId('573a1392f29313caabcdade0'),
#                 'name': 'Megan Richards',
#                 'text': 'Quis dolores ratione maiores optio repudiandae '
#                         'impedit nulla. Eius excepturi animi voluptas est. '
#                         'Velit sunt aliquid cum quae dolore ut. Tempore fugiat '
#                         'eligendi illum vero.'},
#                {'_id': '573a1392f29313caabcdade0-Rast-194777498.0',
#                 'date': datetime.datetime(1976, 3, 4, 3, 51, 38),
#                 'email': 'luke_barnes@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcdade0'),
#                 'name': 'Rast',
#                 'text': 'Iusto dolorem suscipit consequuntur. Eligendi porro '
#                         'explicabo maxime.'}]},
#  {'_id': ObjectId('573a1392f29313caabcdb269'),
#   'comments': [{'_id': '573a1392f29313caabcdb269-Samwell Tarly-245953498.0',
#                 'date': datetime.datetime(1977, 10, 17, 12, 24, 58),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcdb269'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Excepturi veniam dolorem quae at assumenda. Saepe '
#                         'esse provident aut mollitia. Quae magnam quaerat '
#                         'saepe error eius.'}]},
#  {'_id': ObjectId('573a1392f29313caabcdb7c1'),
#   'comments': [{'_id': '573a1392f29313caabcdb7c1-Jeffrey Roberts-391611705.0',
#                 'date': datetime.datetime(1982, 5, 30, 9, 1, 45),
#                 'email': 'jeffrey_roberts@fakegmail.com',
#                 'movie_id': ObjectId('573a1392f29313caabcdb7c1'),
#                 'name': 'Jeffrey Roberts',
#                 'text': 'Iure tempore est eum quo adipisci. Quasi adipisci '
#                         'quae similique. Asperiores quia deserunt aut beatae '
#                         'ex debitis quaerat.'},
#                {'_id': '573a1392f29313caabcdb7c1-Samwell Tarly-1270072.0',
#                 'date': datetime.datetime(1970, 1, 15, 11, 47, 52),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcdb7c1'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Praesentium sunt esse a quos earum aspernatur. '
#                         'Praesentium voluptas quasi voluptatibus quod. Iste '
#                         'commodi minima alias ex quae.'}]},
#  {'_id': ObjectId('573a1392f29313caabcdbabd'),
#   'comments': [{'_id': '573a1392f29313caabcdbabd-Loras Tyrell-1240719957.0',
#                 'date': datetime.datetime(2009, 4, 26, 0, 25, 57),
#                 'email': 'finn_jones@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcdbabd'),
#                 'name': 'Loras Tyrell',
#                 'text': 'Eaque sint autem quis quia cupiditate delectus. In in '
#                         'provident consequatur placeat nobis laborum odio. '
#                         'Sequi dolore placeat nulla.'},
#                {'_id': '573a1392f29313caabcdbabd-Samwell Tarly-556540006.0',
#                 'date': datetime.datetime(1987, 8, 21, 6, 26, 46),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcdbabd'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Aspernatur quasi adipisci reiciendis. Vero '
#                         'consequatur ipsa voluptates ex unde eaque. Sequi '
#                         'error molestias quod temporibus necessitatibus.'},
#                {'_id': '573a1392f29313caabcdbabd-Michael Day-28198662.0',
#                 'date': datetime.datetime(1970, 11, 23, 3, 57, 42),
#                 'email': 'michael_day@fakegmail.com',
#                 'movie_id': ObjectId('573a1392f29313caabcdbabd'),
#                 'name': 'Michael Day',
#                 'text': 'Quidem nam quod quas animi. Mollitia reprehenderit '
#                         'numquam cumque dolorum.'}]},
#  {'_id': ObjectId('573a1392f29313caabcdbbfa'),
#   'comments': [{'_id': '573a1392f29313caabcdbbfa-Donna Russell-1357761555.0',
#                 'date': datetime.datetime(2013, 1, 9, 14, 59, 15),
#                 'email': 'donna_russell@fakegmail.com',
#                 'movie_id': ObjectId('573a1392f29313caabcdbbfa'),
#                 'name': 'Donna Russell',
#                 'text': 'Dicta doloribus voluptate ab. Nulla quae voluptatibus '
#                         'consectetur accusantium commodi aperiam vero eos. '
#                         'Asperiores natus aut nobis corporis. Culpa iure '
#                         'voluptate consequuntur vero saepe odio.'},
#                {'_id': '573a1392f29313caabcdbbfa-Morgan Smith-658156407.0',
#                 'date': datetime.datetime(1990, 11, 9, 8, 13, 27),
#                 'email': 'morgan_smith@fakegmail.com',
#                 'movie_id': ObjectId('573a1392f29313caabcdbbfa'),
#                 'name': 'Morgan Smith',
#                 'text': 'Nulla id aut dicta pariatur aspernatur saepe. Porro '
#                         'ullam nisi amet voluptatem vitae qui ipsa.\n'
#                         'Excepturi facilis iure dolores magnam quas. Odio '
#                         'maiores culpa repellat. Ut itaque vel delectus '
#                         'eveniet.'},
#                {'_id': '573a1392f29313caabcdbbfa-Samwell Tarly-190915874.0',
#                 'date': datetime.datetime(1976, 1, 19, 11, 11, 14),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1392f29313caabcdbbfa'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Delectus sapiente dolorum quod. Deserunt aspernatur '
#                         'reprehenderit optio dolorum sapiente. Consequatur '
#                         'explicabo esse praesentium ut recusandae numquam '
#                         'repellat repellat.'}]},
#  {'_id': ObjectId('573a1393f29313caabcdc8de'),
#   'comments': [{'_id': '573a1393f29313caabcdc8de-Lancel Lannister-507495959.0',
#                 'date': datetime.datetime(1986, 1, 30, 14, 5, 59),
#                 'email': 'eugene_simon@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdc8de'),
#                 'name': 'Lancel Lannister',
#                 'text': 'Quisquam odio natus esse. A facilis cumque excepturi '
#                         'corporis excepturi quam ipsa reprehenderit. Impedit '
#                         'accusamus voluptatum placeat. Amet labore facere '
#                         'aliquam porro commodi illo totam deserunt.'},
#                {'_id': '573a1393f29313caabcdc8de-Samwell Tarly-166405229.0',
#                 'date': datetime.datetime(1975, 4, 10, 19, 40, 29),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdc8de'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Sit voluptas hic officiis praesentium accusamus '
#                         'molestias vero vel. Suscipit dolor esse aperiam. '
#                         'Soluta alias quisquam in perferendis aliquam sit modi '
#                         'animi. Consequatur qui debitis amet enim.'}]},
#  {'_id': ObjectId('573a1393f29313caabcdce5b'),
#   'comments': [{'_id': '573a1393f29313caabcdce5b-Samwell Tarly-616758346.0',
#                 'date': datetime.datetime(1989, 7, 18, 5, 45, 46),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdce5b'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Blanditiis amet cum alias corporis repudiandae quos '
#                         'magni. Sunt nisi quis eveniet magnam commodi quaerat '
#                         'sint impedit. Accusamus accusamus recusandae delectus '
#                         'reprehenderit architecto porro rem.'}]},
#  {'_id': ObjectId('573a1393f29313caabcdd027'),
#   'comments': [{'_id': '573a1393f29313caabcdd027-Samwell Tarly-1287460724.0',
#                 'date': datetime.datetime(2010, 10, 18, 23, 58, 44),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdd027'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Ipsa accusamus distinctio deserunt numquam '
#                         'consequuntur. Veritatis vitae explicabo praesentium '
#                         'in voluptatem. Possimus explicabo voluptates '
#                         'provident minima quae eaque.'},
#                {'_id': '573a1393f29313caabcdd027-Jon Snow-635485072.0',
#                 'date': datetime.datetime(1990, 2, 19, 22, 37, 52),
#                 'email': 'kit_harington@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdd027'),
#                 'name': 'Jon Snow',
#                 'text': 'Facere officiis quidem fugit labore. Consequatur '
#                         'doloremque tempore blanditiis perferendis. Quos '
#                         'provident sit sequi. Laudantium maiores iusto dolore '
#                         'beatae ducimus molestiae minima consequatur.'},
#                {'_id': '573a1393f29313caabcdd027-Brienne of Tarth-583774410.0',
#                 'date': datetime.datetime(1988, 7, 1, 11, 33, 30),
#                 'email': 'gwendoline_christie@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdd027'),
#                 'name': 'Brienne of Tarth',
#                 'text': 'Assumenda architecto totam est saepe. Deserunt omnis '
#                         'voluptatem unde consequuntur nobis. Quibusdam rem '
#                         'dicta eius harum illum earum aperiam.'},
#                {'_id': '573a1393f29313caabcdd027-Lisa Silva-172667686.0',
#                 'date': datetime.datetime(1975, 6, 22, 7, 14, 46),
#                 'email': 'lisa_silva@fakegmail.com',
#                 'movie_id': ObjectId('573a1393f29313caabcdd027'),
#                 'name': 'Lisa Silva',
#                 'text': 'Beatae hic iusto possimus numquam ratione distinctio '
#                         'cupiditate. Quasi sequi veniam unde sit. Deleniti ea '
#                         'consequatur quibusdam adipisci beatae nobis facere. '
#                         'Blanditiis in minus in.'}]},
#  {'_id': ObjectId('573a1393f29313caabcdd615'),
#   'comments': [{'_id': '573a1393f29313caabcdd615-Samwell Tarly-623051169.0',
#                 'date': datetime.datetime(1989, 9, 29, 1, 46, 9),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdd615'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Magnam libero necessitatibus suscipit animi. Quaerat '
#                         'facilis dolore recusandae voluptate similique. Labore '
#                         'officia libero dolore.'}]},
#  {'_id': ObjectId('573a1393f29313caabcdd74c'),
#   'comments': [{'_id': '573a1393f29313caabcdd74c-Samwell Tarly-828422582.0',
#                 'date': datetime.datetime(1996, 4, 2, 0, 23, 2),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdd74c'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Eius non et quisquam voluptas quibusdam dolore. Earum '
#                         'ut qui ullam unde maiores distinctio odio modi.'},
#                {'_id': '573a1393f29313caabcdd74c-Viserys Targaryen-503324552.0',
#                 'date': datetime.datetime(1985, 12, 13, 7, 22, 32),
#                 'email': 'harry_lloyd@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdd74c'),
#                 'name': 'Viserys Targaryen',
#                 'text': 'Ipsa repudiandae laudantium laboriosam repellendus ea '
#                         'quisquam dolor. Odit molestiae vel nobis tenetur. '
#                         'Accusamus officia iusto placeat ullam. Accusantium '
#                         'officia quam tempora quia ut.'},
#                {'_id': '573a1393f29313caabcdd74c-Donna Russell-468034752.0',
#                 'date': datetime.datetime(1984, 10, 30, 20, 39, 12),
#                 'email': 'donna_russell@fakegmail.com',
#                 'movie_id': ObjectId('573a1393f29313caabcdd74c'),
#                 'name': 'Donna Russell',
#                 'text': 'Architecto facilis ex recusandae sapiente molestiae '
#                         'officia sed amet. Amet beatae sit dolor. Doloremque '
#                         'optio doloremque odio quo dignissimos '
#                         'necessitatibus.'},
#                {'_id': '573a1393f29313caabcdd74c-Jeor Mormont-461648559.0',
#                 'date': datetime.datetime(1984, 8, 17, 23, 42, 39),
#                 'email': 'james_cosmo@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdd74c'),
#                 'name': 'Jeor Mormont',
#                 'text': 'Dolorem nesciunt architecto labore nihil cum aliquid. '
#                         'Fugiat ad deleniti illum ullam nihil ut. Fuga iure '
#                         'occaecati odio cum.'}]},
#  {'_id': ObjectId('573a1393f29313caabcdded3'),
#   'comments': [{'_id': '573a1393f29313caabcdded3-Samwell Tarly-893430956.0',
#                 'date': datetime.datetime(1998, 4, 24, 11, 15, 56),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdded3'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Delectus nesciunt corrupti reiciendis. Modi natus ab '
#                         'dignissimos blanditiis odit quidem dolor. Tempora '
#                         'deserunt blanditiis odit nemo iure iste.'},
#                {'_id': '573a1393f29313caabcdded3-Selyse Baratheon-502483452.0',
#                 'date': datetime.datetime(1985, 12, 3, 13, 44, 12),
#                 'email': 'tara_fitzgerald@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcdded3'),
#                 'name': 'Selyse Baratheon',
#                 'text': 'Ab ipsum est odit commodi fugit. Cum voluptas dolorem '
#                         'consequatur asperiores. Laudantium unde quasi '
#                         'harum.'}]},
#  {'_id': ObjectId('573a1393f29313caabcde458'),
#   'comments': [{'_id': '573a1393f29313caabcde458-Greg Powell-909559600.0',
#                 'date': datetime.datetime(1998, 10, 28, 2, 26, 40),
#                 'email': 'greg_powell@fakegmail.com',
#                 'movie_id': ObjectId('573a1393f29313caabcde458'),
#                 'name': 'Greg Powell',
#                 'text': 'Maiores recusandae temporibus et sequi ducimus. Cum '
#                         'explicabo nesciunt adipisci sapiente. Unde occaecati '
#                         'perferendis incidunt quasi enim ea.'},
#                {'_id': '573a1393f29313caabcde458-Samwell Tarly-883936662.0',
#                 'date': datetime.datetime(1998, 1, 4, 12, 57, 42),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcde458'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Itaque voluptatem quia facilis amet eaque. Unde '
#                         'nostrum id ullam a soluta iste nemo. Odio quaerat '
#                         'vitae vitae. Occaecati quibusdam doloribus officiis '
#                         'error ut.'},
#                {'_id': '573a1393f29313caabcde458-Kristen Schmidt-318835621.0',
#                 'date': datetime.datetime(1980, 2, 8, 0, 27, 1),
#                 'email': 'kristen_schmidt@fakegmail.com',
#                 'movie_id': ObjectId('573a1393f29313caabcde458'),
#                 'name': 'Kristen Schmidt',
#                 'text': 'Dolorem beatae eius sequi praesentium suscipit fugit '
#                         'optio. Impedit voluptatum placeat pariatur asperiores '
#                         'provident possimus. A distinctio accusamus sapiente '
#                         'voluptatum at quo provident.'},
#                {'_id': '573a1393f29313caabcde458-Maester Aemon-80927601.0',
#                 'date': datetime.datetime(1972, 7, 25, 11, 53, 21),
#                 'email': 'peter_vaughan@gameofthron.es',
#                 'movie_id': ObjectId('573a1393f29313caabcde458'),
#                 'name': 'Maester Aemon',
#                 'text': 'Architecto cupiditate laboriosam velit repellendus. '
#                         'Ut unde ex cupiditate et. Sequi exercitationem in '
#                         'doloribus maxime consequuntur harum.'}]},
#  {'_id': ObjectId('573a1394f29313caabcde60c'),
#   'comments': [{'_id': '573a1394f29313caabcde60c-Heather Leonard-1050139490.0',
#                 'date': datetime.datetime(2003, 4, 12, 5, 24, 50),
#                 'email': 'heather_leonard@fakegmail.com',
#                 'movie_id': ObjectId('573a1394f29313caabcde60c'),
#                 'name': 'Heather Leonard',
#                 'text': 'Eum fugit ullam enim repudiandae nobis ex. Quos '
#                         'necessitatibus rerum fugit at minima tempora.'},
#                {'_id': '573a1394f29313caabcde60c-Samwell Tarly-119055940.0',
#                 'date': datetime.datetime(1973, 10, 9, 19, 5, 40),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1394f29313caabcde60c'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Laudantium soluta error non fugit est qui soluta. '
#                         'Dolorum dignissimos ut odio aliquam. Soluta ex '
#                         'recusandae corrupti mollitia dolore voluptate nobis '
#                         'corporis.'}]},
#  {'_id': ObjectId('573a1394f29313caabcdeeaf'),
#   'comments': [{'_id': '573a1394f29313caabcdeeaf-Hodor-1146662040.0',
#                 'date': datetime.datetime(2006, 5, 3, 9, 14),
#                 'email': 'kristian_nairn@gameofthron.es',
#                 'movie_id': ObjectId('573a1394f29313caabcdeeaf'),
#                 'name': 'Hodor',
#                 'text': 'Veritatis quia ab dolorem quae qui veritatis. Ipsam '
#                         'corporis rem reiciendis vel.'},
#                {'_id': '573a1394f29313caabcdeeaf-Samwell Tarly-317998971.0',
#                 'date': datetime.datetime(1980, 1, 29, 8, 2, 51),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1394f29313caabcdeeaf'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Tempore libero perspiciatis optio architecto neque. '
#                         'Omnis rerum soluta natus. Esse laborum vero mollitia '
#                         'quos quasi.'}]},
#  {'_id': ObjectId('573a1394f29313caabcdf389'),
#   'comments': [{'_id': '573a1394f29313caabcdf389-Samwell Tarly-1170443914.0',
#                 'date': datetime.datetime(2007, 2, 2, 14, 18, 34),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1394f29313caabcdf389'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Deserunt sint provident explicabo quod laudantium '
#                         'libero sunt. Inventore rem earum repellat '
#                         'repudiandae. Rerum possimus possimus quasi officiis. '
#                         'Inventore similique itaque voluptatibus aperiam.'},
#                {'_id': '573a1394f29313caabcdf389-Julia Nichols-46339674.0',
#                 'date': datetime.datetime(1971, 6, 21, 4, 7, 54),
#                 'email': 'julia_nichols@fakegmail.com',
#                 'movie_id': ObjectId('573a1394f29313caabcdf389'),
#                 'name': 'Julia Nichols',
#                 'text': 'Dignissimos iste quam soluta id nesciunt accusantium '
#                         'totam. Ipsa ab itaque optio minus. Impedit nihil '
#                         'aliquid doloribus sint est officiis autem.'}]},
#  {'_id': ObjectId('573a1394f29313caabcdfc0a'),
#   'comments': [{'_id': '573a1394f29313caabcdfc0a-Jonathon '
#                        'Mccullough-916286698.0',
#                 'date': datetime.datetime(1999, 1, 13, 23, 4, 58),
#                 'email': 'jonathon_mccullough@fakegmail.com',
#                 'movie_id': ObjectId('573a1394f29313caabcdfc0a'),
#                 'name': 'Jonathon Mccullough',
#                 'text': 'Odio odit libero dicta harum et labore. Ex aperiam '
#                         'distinctio ipsum. Quaerat assumenda sequi mollitia '
#                         'eum dolor exercitationem. Culpa accusamus quidem '
#                         'ipsum laudantium aut veniam distinctio fugit.'},
#                {'_id': '573a1394f29313caabcdfc0a-Ros-846858481.0',
#                 'date': datetime.datetime(1996, 11, 1, 9, 28, 1),
#                 'email': 'esme_bianco@gameofthron.es',
#                 'movie_id': ObjectId('573a1394f29313caabcdfc0a'),
#                 'name': 'Ros',
#                 'text': 'Atque doloribus dignissimos esse pariatur quod. '
#                         'Fugiat eligendi error ipsum nobis. Aperiam magni ipsa '
#                         'minima nisi totam in. Fuga quisquam dicta sed vel '
#                         'iure earum.'},
#                {'_id': '573a1394f29313caabcdfc0a-Samwell Tarly-723547204.0',
#                 'date': datetime.datetime(1992, 12, 5, 4, 20, 4),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1394f29313caabcdfc0a'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Inventore eius quaerat corrupti. Numquam nisi tempora '
#                         'nam libero ipsum quasi delectus.'}]},
#  {'_id': ObjectId('573a1394f29313caabce023a'),
#   'comments': [{'_id': '573a1394f29313caabce023a-Garrett Obrien-1497389364.0',
#                 'date': datetime.datetime(2017, 6, 13, 17, 29, 24),
#                 'email': 'garrett_obrien@fakegmail.com',
#                 'movie_id': ObjectId('573a1394f29313caabce023a'),
#                 'name': 'Garrett Obrien',
#                 'text': 'Ipsa rerum exercitationem veritatis eveniet repellat '
#                         'ex suscipit. Mollitia nobis libero impedit enim porro '
#                         'odio nostrum. Laboriosam reiciendis eius perspiciatis '
#                         'ipsum.'},
#                {'_id': '573a1394f29313caabce023a-Samwell Tarly-363504803.0',
#                 'date': datetime.datetime(1981, 7, 9, 1, 33, 23),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1394f29313caabce023a'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Vero optio facere porro modi quidem assumenda. '
#                         'Occaecati laboriosam totam temporibus ut animi '
#                         'expedita. Quasi dolorem omnis perspiciatis ratione '
#                         'accusantium nemo quaerat.'},
#                {'_id': '573a1394f29313caabce023a-Donna Russell-231596668.0',
#                 'date': datetime.datetime(1977, 5, 4, 8, 24, 28),
#                 'email': 'donna_russell@fakegmail.com',
#                 'movie_id': ObjectId('573a1394f29313caabce023a'),
#                 'name': 'Donna Russell',
#                 'text': 'Assumenda sapiente accusantium eveniet animi '
#                         'architecto nesciunt. Id reiciendis ad molestiae '
#                         'aspernatur beatae ad doloribus ex. Vero asperiores '
#                         'rerum cumque repudiandae officia beatae.'}]},
#  {'_id': ObjectId('573a1395f29313caabce1854'),
#   'comments': [{'_id': '573a1395f29313caabce1854-Samwell Tarly-775273546.0',
#                 'date': datetime.datetime(1994, 7, 26, 21, 45, 46),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1395f29313caabce1854'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Nulla incidunt molestiae eos consequatur consectetur. '
#                         'Voluptates saepe mollitia eius odio fuga id inventore '
#                         'laborum. Omnis voluptas nesciunt alias consequuntur.'},
#                {'_id': '573a1395f29313caabce1854-Cameron Duran-681501874.0',
#                 'date': datetime.datetime(1991, 8, 6, 14, 4, 34),
#                 'email': 'cameron_duran@fakegmail.com',
#                 'movie_id': ObjectId('573a1395f29313caabce1854'),
#                 'name': 'Cameron Duran',
#                 'text': 'Repellat soluta fuga nam. Voluptatibus perspiciatis '
#                         'ipsa possimus amet voluptatum inventore. Commodi '
#                         'nobis molestiae unde delectus.'}]},
#  {'_id': ObjectId('573a1395f29313caabce1b1b'),
#   'comments': [{'_id': '573a1395f29313caabce1b1b-Daario Naharis-449140512.0',
#                 'date': datetime.datetime(1984, 3, 26, 4, 15, 12),
#                 'email': 'michiel_huisman@gameofthron.es',
#                 'movie_id': ObjectId('573a1395f29313caabce1b1b'),
#                 'name': 'Daario Naharis',
#                 'text': 'Amet unde molestias ea doloribus dignissimos. Labore '
#                         'dicta autem dolores quam. Mollitia beatae rem cum '
#                         'aliquam mollitia. Fugiat sunt dolor harum animi alias '
#                         'dolorum.'},
#                {'_id': '573a1395f29313caabce1b1b-Samwell Tarly-363977427.0',
#                 'date': datetime.datetime(1981, 7, 14, 12, 50, 27),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1395f29313caabce1b1b'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Doloribus nesciunt sequi ad in facilis. Repudiandae '
#                         'ipsam voluptas nemo et mollitia laborum eaque. '
#                         'Excepturi illum quae non. Fuga deleniti vel totam '
#                         'quisquam.'}]},
#  {'_id': ObjectId('573a1395f29313caabce1b20'),
#   'comments': [{'_id': '573a1395f29313caabce1b20-Samwell Tarly-75642202.0',
#                 'date': datetime.datetime(1972, 5, 25, 7, 43, 22),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1395f29313caabce1b20'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Perferendis laudantium maiores velit saepe dolorum. '
#                         'Similique vero nobis ab vero minima totam. Cumque '
#                         'excepturi harum necessitatibus voluptates.'}]},
#  {'_id': ObjectId('573a1395f29313caabce215c'),
#   'comments': [{'_id': '573a1395f29313caabce215c-Samwell Tarly-158858226.0',
#                 'date': datetime.datetime(1975, 1, 13, 10, 17, 6),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1395f29313caabce215c'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Soluta est repellendus et fugit. Cupiditate optio '
#                         'minima totam nisi ratione omnis. Dolore deserunt '
#                         'omnis ad corrupti. Doloribus animi molestiae '
#                         'quasi.'}]},
#  {'_id': ObjectId('573a1395f29313caabce266e'),
#   'comments': [{'_id': '573a1395f29313caabce266e-Patricia Good-1444689462.0',
#                 'date': datetime.datetime(2015, 10, 12, 18, 37, 42),
#                 'email': 'patricia_good@fakegmail.com',
#                 'movie_id': ObjectId('573a1395f29313caabce266e'),
#                 'name': 'Patricia Good',
#                 'text': 'Aliquid laboriosam illum maiores doloremque officiis. '
#                         'Quia eveniet quisquam vitae quisquam. Atque laborum '
#                         'adipisci pariatur vel.'},
#                {'_id': '573a1395f29313caabce266e-Samwell Tarly-34433019.0',
#                 'date': datetime.datetime(1971, 2, 3, 7, 43, 39),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1395f29313caabce266e'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Dolorem quidem aspernatur quaerat quisquam debitis. '
#                         'Tempora nobis eaque saepe. Quod tempora sint dolores '
#                         'accusantium ipsum ad illo.'}]},
#  {'_id': ObjectId('573a1395f29313caabce2746'),
#   'comments': [{'_id': '573a1395f29313caabce2746-Samwell Tarly-1256215016.0',
#                 'date': datetime.datetime(2009, 10, 22, 8, 36, 56),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1395f29313caabce2746'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Saepe vel ad voluptas a. Voluptates rerum nisi iste '
#                         'id voluptate quia. Optio officiis error deleniti '
#                         'porro.'},
#                {'_id': '573a1395f29313caabce2746-Missandei-415487193.0',
#                 'date': datetime.datetime(1983, 3, 2, 16, 6, 33),
#                 'email': 'nathalie_emmanuel@gameofthron.es',
#                 'movie_id': ObjectId('573a1395f29313caabce2746'),
#                 'name': 'Missandei',
#                 'text': 'Quo dolorum molestiae culpa expedita. Adipisci '
#                         'voluptatum autem tempore fuga voluptatem. Accusamus '
#                         'necessitatibus officia nesciunt a. Vitae ea sequi '
#                         'illum optio odit omnis.'},
#                {'_id': '573a1395f29313caabce2746-Blake Fitzgerald-183781717.0',
#                 'date': datetime.datetime(1975, 10, 28, 21, 28, 37),
#                 'email': 'blake_fitzgerald@fakegmail.com',
#                 'movie_id': ObjectId('573a1395f29313caabce2746'),
#                 'name': 'Blake Fitzgerald',
#                 'text': 'Fugiat ullam nesciunt sed doloremque ab expedita. '
#                         'Nisi laudantium quisquam cum quasi delectus ab animi. '
#                         'Qui tempore at velit a illo aliquid. Totam porro amet '
#                         'nobis ducimus quaerat.'}]},
#  {'_id': ObjectId('573a1396f29313caabce35cb'),
#   'comments': [{'_id': '573a1396f29313caabce35cb-Samwell Tarly-261123466.0',
#                 'date': datetime.datetime(1978, 4, 11, 1, 17, 46),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1396f29313caabce35cb'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Dolorem nihil quas aut nisi tempora laboriosam '
#                         'tenetur. Amet temporibus eius vitae asperiores. '
#                         'Temporibus repudiandae labore vitae.'}]},
#  {'_id': ObjectId('573a1396f29313caabce372c'),
#   'comments': [{'_id': '573a1396f29313caabce372c-Samwell Tarly-1080878941.0',
#                 'date': datetime.datetime(2004, 4, 1, 23, 9, 1),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1396f29313caabce372c'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Repudiandae quia saepe quas est hic velit. Dicta '
#                         'consequuntur in perferendis voluptatum sit architecto '
#                         'fuga. Libero et rerum animi quod similique. Delectus '
#                         'laboriosam deserunt hic temporibus atque.'},
#                {'_id': '573a1396f29313caabce372c-Eric Navarro-786315094.0',
#                 'date': datetime.datetime(1994, 12, 1, 15, 51, 34),
#                 'email': 'eric_navarro@fakegmail.com',
#                 'movie_id': ObjectId('573a1396f29313caabce372c'),
#                 'name': 'Eric Navarro',
#                 'text': 'Nobis accusantium excepturi soluta voluptatum maxime '
#                         'esse. Perspiciatis repellendus hic quae fugiat. '
#                         'Similique itaque at commodi sequi officiis optio.'}]},
#  {'_id': ObjectId('573a1396f29313caabce3cd5'),
#   'comments': [{'_id': '573a1396f29313caabce3cd5-Jorah Mormont-1304808508.0',
#                 'date': datetime.datetime(2011, 5, 7, 18, 48, 28),
#                 'email': 'iain_glen@gameofthron.es',
#                 'movie_id': ObjectId('573a1396f29313caabce3cd5'),
#                 'name': 'Jorah Mormont',
#                 'text': 'Voluptatum commodi odit rem cupiditate fugiat ea. '
#                         'Incidunt provident natus a iste pariatur velit hic '
#                         'sit. Atque iste similique id aliquid eos vero '
#                         'doloribus.'},
#                {'_id': '573a1396f29313caabce3cd5-Samwell Tarly-654875206.0',
#                 'date': datetime.datetime(1990, 10, 2, 9, 46, 46),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1396f29313caabce3cd5'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Ad odio deserunt ipsam quidem. Quam iste cum nesciunt '
#                         'non suscipit unde iure. Distinctio consequatur modi '
#                         'ea repellat. Ipsam ipsam ipsam autem repellat nemo '
#                         'doloribus.'}]},
#  {'_id': ObjectId('573a1396f29313caabce4062'),
#   'comments': [{'_id': '573a1396f29313caabce4062-Ygritte-1147653702.0',
#                 'date': datetime.datetime(2006, 5, 14, 20, 41, 42),
#                 'email': 'rose_leslie@gameofthron.es',
#                 'movie_id': ObjectId('573a1396f29313caabce4062'),
#                 'name': 'Ygritte',
#                 'text': 'Quasi quae laudantium molestias molestiae ratione. '
#                         'Repudiandae quis quod quos sint atque eius '
#                         'distinctio. Ad libero soluta illo maiores occaecati '
#                         'culpa illum.'},
#                {'_id': '573a1396f29313caabce4062-Samwell Tarly-554688109.0',
#                 'date': datetime.datetime(1987, 7, 30, 20, 1, 49),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1396f29313caabce4062'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Aliquid a deleniti at sint quia. Molestias veniam '
#                         'inventore temporibus sunt non. Illum architecto error '
#                         'totam corporis vero. Repellat assumenda veniam '
#                         'adipisci ipsum eveniet et eaque omnis.'}]},
#  {'_id': ObjectId('573a1396f29313caabce4100'),
#   'comments': [{'_id': '573a1396f29313caabce4100-Samwell Tarly-99882466.0',
#                 'date': datetime.datetime(1973, 3, 1, 20, 7, 46),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1396f29313caabce4100'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Deserunt consequuntur occaecati numquam natus quo. '
#                         'Explicabo corporis sit quia rem commodi dicta '
#                         'debitis. Libero id aperiam culpa similique modi nam '
#                         'laboriosam.'}]},
#  {'_id': ObjectId('573a1396f29313caabce4162'),
#   'comments': [{'_id': '573a1396f29313caabce4162-Samwell Tarly-658057967.0',
#                 'date': datetime.datetime(1990, 11, 8, 4, 52, 47),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1396f29313caabce4162'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Ut totam quibusdam earum eos veritatis omnis '
#                         'exercitationem. Tenetur hic enim sequi voluptatibus '
#                         'tempora cum magnam.'}]},
#  {'_id': ObjectId('573a1396f29313caabce4d58'),
#   'comments': [{'_id': '573a1396f29313caabce4d58-Donna Smith-1452675086.0',
#                 'date': datetime.datetime(2016, 1, 13, 3, 51, 26),
#                 'email': 'donna_smith@fakegmail.com',
#                 'movie_id': ObjectId('573a1396f29313caabce4d58'),
#                 'name': 'Donna Smith',
#                 'text': 'Nihil quia minima architecto mollitia. Voluptatum '
#                         'laudantium nihil libero rerum perferendis. Assumenda '
#                         'modi nam iure quia omnis laborum dignissimos '
#                         'reiciendis.'},
# ...
#                 'name': 'Lisa Silva',
#                 'text': 'Saepe commodi placeat magni optio sint pariatur fuga. '
#                         'Dolorum labore accusantium est similique harum ea '
#                         'culpa. Perferendis repellendus illum placeat.'},
#                {'_id': '573a13e7f29313caabdc861c-Samwell Tarly-646909828.0',
#                 'date': datetime.datetime(1990, 7, 2, 5, 10, 28),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13e7f29313caabdc861c'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Accusamus qui quaerat error fugiat. Praesentium odio '
#                         'quam deserunt ipsum in quasi vel. Ullam veritatis '
#                         'dicta natus accusamus sapiente labore. Magni nam unde '
#                         'quidem iste similique.'},
#                {'_id': '573a13e7f29313caabdc861c-Theresa Holmes-373158418.0',
#                 'date': datetime.datetime(1981, 10, 28, 18, 6, 58),
#                 'email': 'theresa_holmes@fakegmail.com',
#                 'movie_id': ObjectId('573a13e7f29313caabdc861c'),
#                 'name': 'Theresa Holmes',
#                 'text': 'Vero voluptatem ipsam voluptatum adipisci esse. '
#                         'Voluptatem quo nemo id dolorum. In ab consequuntur '
#                         'voluptas sit exercitationem hic error.'}]},
#  {'_id': ObjectId('573a13e9f29313caabdcd682'),
#   'comments': [{'_id': '573a13e9f29313caabdcd682-Samwell Tarly-745013965.0',
#                 'date': datetime.datetime(1993, 8, 10, 16, 19, 25),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13e9f29313caabdcd682'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Incidunt sunt odio numquam aliquid. Magnam quis eaque '
#                         'quis explicabo dolore consectetur eius. Rem '
#                         'perferendis odio aspernatur temporibus. Veritatis '
#                         'aperiam exercitationem voluptatibus natus earum.'},
#                {'_id': '573a13e9f29313caabdcd682-Taylor Hill-514102601.0',
#                 'date': datetime.datetime(1986, 4, 17, 1, 16, 41),
#                 'email': 'taylor_hill@fakegmail.com',
#                 'movie_id': ObjectId('573a13e9f29313caabdcd682'),
#                 'name': 'Taylor Hill',
#                 'text': 'Quo quia ipsam voluptatum sapiente voluptatem. Cum '
#                         'explicabo nam amet quasi quo reprehenderit. Qui eius '
#                         'ducimus occaecati assumenda qui alias.'}]},
#  {'_id': ObjectId('573a13eaf29313caabdce255'),
#   'comments': [{'_id': '573a13eaf29313caabdce255-Samwell Tarly-327236893.0',
#                 'date': datetime.datetime(1980, 5, 15, 7, 8, 13),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13eaf29313caabdce255'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Blanditiis tempore ut libero saepe odit esse soluta '
#                         'tempora. Eligendi doloribus fugiat sed. Cum voluptas '
#                         'officiis quisquam eveniet.'}]},
#  {'_id': ObjectId('573a13eaf29313caabdce33d'),
#   'comments': [{'_id': '573a13eaf29313caabdce33d-Samwell Tarly-450043927.0',
#                 'date': datetime.datetime(1984, 4, 5, 15, 12, 7),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13eaf29313caabdce33d'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Et itaque assumenda necessitatibus magni. Dolor sed '
#                         'adipisci illo nisi officiis cum debitis. Rem dolorum '
#                         'aspernatur labore ratione iure.'}]},
#  {'_id': ObjectId('573a13ecf29313caabdd2c5f'),
#   'comments': [{'_id': '573a13ecf29313caabdd2c5f-Samwell Tarly-1390857986.0',
#                 'date': datetime.datetime(2014, 1, 27, 16, 26, 26),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13ecf29313caabdd2c5f'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Doloribus laborum cupiditate sint ratione. Est '
#                         'architecto reprehenderit recusandae itaque. Mollitia '
#                         'rerum quod quis.'},
#                {'_id': '573a13ecf29313caabdd2c5f-Brenda Martin-1130700952.0',
#                 'date': datetime.datetime(2005, 10, 30, 14, 35, 52),
#                 'email': 'brenda_martin@fakegmail.com',
#                 'movie_id': ObjectId('573a13ecf29313caabdd2c5f'),
#                 'name': 'Brenda Martin',
#                 'text': 'Suscipit porro ut eaque excepturi corrupti quas. Unde '
#                         'similique commodi aliquid assumenda enim alias. '
#                         'Nesciunt quam natus iusto. Deserunt pariatur '
#                         'reprehenderit totam similique.'},
#                {'_id': '573a13ecf29313caabdd2c5f-Amy Phillips-308419607.0',
#                 'date': datetime.datetime(1979, 10, 10, 12, 6, 47),
#                 'email': 'amy_phillips@fakegmail.com',
#                 'movie_id': ObjectId('573a13ecf29313caabdd2c5f'),
#                 'name': 'Amy Phillips',
#                 'text': 'Eos nisi sit qui asperiores. Numquam vitae repellat '
#                         'rerum. Hic quasi eum dolore nisi nulla. Velit a non '
#                         'ab error asperiores nisi perspiciatis ut.'}]},
#  {'_id': ObjectId('573a13f0f29313caabdd96b1'),
#   'comments': [{'_id': '573a13f0f29313caabdd96b1-Podrick Payne-1242541898.0',
#                 'date': datetime.datetime(2009, 5, 17, 2, 31, 38),
#                 'email': 'daniel_portman@gameofthron.es',
#                 'movie_id': ObjectId('573a13f0f29313caabdd96b1'),
#                 'name': 'Podrick Payne',
#                 'text': 'Voluptatem maxime saepe nobis tempore. Ipsa doloribus '
#                         'nulla recusandae.'},
#                {'_id': '573a13f0f29313caabdd96b1-Samwell Tarly-419267577.0',
#                 'date': datetime.datetime(1983, 4, 15, 10, 12, 57),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13f0f29313caabdd96b1'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Ipsa culpa quas nemo magni molestiae. Ex dignissimos '
#                         'nam assumenda labore dolore quaerat porro. Ratione '
#                         'sapiente neque quibusdam dolorum cum.'},
#                {'_id': '573a13f0f29313caabdd96b1-Petyr Baelish-258673947.0',
#                 'date': datetime.datetime(1978, 3, 13, 16, 52, 27),
#                 'email': 'aidan_gillen@gameofthron.es',
#                 'movie_id': ObjectId('573a13f0f29313caabdd96b1'),
#                 'name': 'Petyr Baelish',
#                 'text': 'Corrupti distinctio repellat architecto doloribus '
#                         'delectus consectetur reiciendis. Quam nisi dolorem at '
#                         'possimus sapiente. Et veritatis beatae quam provident '
#                         'vel repellendus.'}]},
#  {'_id': ObjectId('573a13f6f29313caabde538a'),
#   'comments': [{'_id': '573a13f6f29313caabde538a-Michael Moore-959848993.0',
#                 'date': datetime.datetime(2000, 6, 1, 4, 43, 13),
#                 'email': 'michael_moore@fakegmail.com',
#                 'movie_id': ObjectId('573a13f6f29313caabde538a'),
#                 'name': 'Michael Moore',
#                 'text': 'Repellat aspernatur sunt consectetur doloribus. Harum '
#                         'velit saepe corporis recusandae natus assumenda '
#                         'delectus. Non totam numquam sed ipsum aut.'},
#                {'_id': '573a13f6f29313caabde538a-Mrs. Ariana Nunez-815061716.0',
#                 'date': datetime.datetime(1995, 10, 30, 9, 1, 56),
#                 'email': 'mrs._ariana_nunez@fakegmail.com',
#                 'movie_id': ObjectId('573a13f6f29313caabde538a'),
#                 'name': 'Mrs. Ariana Nunez',
#                 'text': 'Quos modi architecto sapiente nobis eaque ipsum est. '
#                         'Repudiandae veniam nam sequi. Impedit blanditiis nemo '
#                         'blanditiis modi accusantium.'},
#                {'_id': '573a13f6f29313caabde538a-Samwell Tarly-309592863.0',
#                 'date': datetime.datetime(1979, 10, 24, 2, 1, 3),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13f6f29313caabde538a'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Placeat aperiam mollitia eligendi quas. Perspiciatis '
#                         'sed id saepe soluta deserunt velit. Ipsum consequatur '
#                         'maxime labore. Doloremque nulla assumenda rem '
#                         'adipisci ut.'}]},
#  {'_id': ObjectId('573a13f7f29313caabde68f4'),
#   'comments': [{'_id': '573a13f7f29313caabde68f4-Catelyn Stark-1499513366.0',
#                 'date': datetime.datetime(2017, 7, 8, 7, 29, 26),
#                 'email': 'michelle_fairley@gameofthron.es',
#                 'movie_id': ObjectId('573a13f7f29313caabde68f4'),
#                 'name': 'Catelyn Stark',
#                 'text': 'Vel quisquam eaque mollitia ipsum. Fugit quisquam '
#                         'aliquid omnis ipsa assumenda quaerat vel. Quas nobis '
#                         'consequuntur enim repellat illo odio suscipit. Quidem '
#                         'fuga fugit mollitia commodi.'},
#                {'_id': '573a13f7f29313caabde68f4-Alliser Thorne-642624065.0',
#                 'date': datetime.datetime(1990, 5, 13, 14, 41, 5),
#                 'email': 'owen_teale@gameofthron.es',
#                 'movie_id': ObjectId('573a13f7f29313caabde68f4'),
#                 'name': 'Alliser Thorne',
#                 'text': 'In dolorem porro nihil aliquid. Vel numquam eos '
#                         'quidem dolorum. Debitis quod sint ducimus fugiat '
#                         'corrupti.'},
#                {'_id': '573a13f7f29313caabde68f4-Samwell Tarly-6655193.0',
#                 'date': datetime.datetime(1970, 3, 18, 19, 39, 53),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13f7f29313caabde68f4'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Sint nemo omnis laudantium qui. Modi quos iusto '
#                         'laudantium dolorem rerum consectetur. Ex dolorem '
#                         'excepturi necessitatibus earum architecto nam '
#                         'enim.'}]},
#  {'_id': ObjectId('573a13f9f29313caabdeb527'),
#   'comments': [{'_id': '573a13f9f29313caabdeb527-Jason Hernandez-870471587.0',
#                 'date': datetime.datetime(1997, 8, 1, 17, 39, 47),
#                 'email': 'jason_hernandez@fakegmail.com',
#                 'movie_id': ObjectId('573a13f9f29313caabdeb527'),
#                 'name': 'Jason Hernandez',
#                 'text': 'Ratione architecto qui reiciendis. Odio voluptates '
#                         'assumenda nesciunt eius ex non.'},
#                {'_id': '573a13f9f29313caabdeb527-Maester Aemon-721890267.0',
#                 'date': datetime.datetime(1992, 11, 16, 0, 4, 27),
#                 'email': 'peter_vaughan@gameofthron.es',
#                 'movie_id': ObjectId('573a13f9f29313caabdeb527'),
#                 'name': 'Maester Aemon',
#                 'text': 'Dolore eligendi saepe ullam labore. Consequatur '
#                         'laborum odit sint blanditiis. Rem fugiat distinctio '
#                         'recusandae repellat omnis.'},
#                {'_id': '573a13f9f29313caabdeb527-Samwell Tarly-595765376.0',
#                 'date': datetime.datetime(1988, 11, 17, 5, 22, 56),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13f9f29313caabdeb527'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Sunt non dolorum adipisci ipsa quod. Minus excepturi '
#                         'laboriosam reprehenderit natus neque aperiam. Modi '
#                         'dolor quam quibusdam aperiam. A nisi soluta quidem '
#                         'molestiae maiores recusandae eaque mollitia.'},
#                {'_id': '573a13f9f29313caabdeb527-Bradley Brooks-429798900.0',
#                 'date': datetime.datetime(1983, 8, 15, 8, 35),
#                 'email': 'bradley_brooks@fakegmail.com',
#                 'movie_id': ObjectId('573a13f9f29313caabdeb527'),
#                 'name': 'Bradley Brooks',
#                 'text': 'Sequi vitae eveniet inventore aspernatur distinctio '
#                         'iste. Minus at velit veniam nesciunt veniam neque '
#                         'dolorum. Laudantium expedita consectetur '
#                         'exercitationem vitae molestiae nam.'},
#                {'_id': '573a13f9f29313caabdeb527-Edward Barrett-411079764.0',
#                 'date': datetime.datetime(1983, 1, 10, 15, 49, 24),
#                 'email': 'edward_barrett@fakegmail.com',
#                 'movie_id': ObjectId('573a13f9f29313caabdeb527'),
#                 'name': 'Edward Barrett',
#                 'text': 'Ex inventore veniam quibusdam facere. Quo laudantium '
#                         'libero optio. Ab placeat dolorum nam nisi ut.'}]},
#  {'_id': ObjectId('573a13faf29313caabdeb9e7'),
#   'comments': [{'_id': '573a13faf29313caabdeb9e7-Kenneth Chandler-1393759708.0',
#                 'date': datetime.datetime(2014, 3, 2, 6, 28, 28),
#                 'email': 'kenneth_chandler@fakegmail.com',
#                 'movie_id': ObjectId('573a13faf29313caabdeb9e7'),
#                 'name': 'Kenneth Chandler',
#                 'text': 'Doloremque repudiandae accusantium voluptate '
#                         'distinctio temporibus unde. Nobis fugiat magnam '
#                         'possimus commodi. Maxime cupiditate eligendi '
#                         'voluptatum ipsum veritatis.'},
#                {'_id': '573a13faf29313caabdeb9e7-Samwell Tarly-808122060.0',
#                 'date': datetime.datetime(1995, 8, 11, 2, 21),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13faf29313caabdeb9e7'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Illo magnam repellat officia eveniet. Ducimus '
#                         'occaecati omnis dolore magni soluta a iusto. Id magni '
#                         'laudantium rerum voluptatibus.'},
#                {'_id': '573a13faf29313caabdeb9e7-Lori Franklin-753696740.0',
#                 'date': datetime.datetime(1993, 11, 19, 3, 12, 20),
#                 'email': 'lori_franklin@fakegmail.com',
#                 'movie_id': ObjectId('573a13faf29313caabdeb9e7'),
#                 'name': 'Lori Franklin',
#                 'text': 'Mollitia quasi ea dolorem amet. Corporis ipsa quam '
#                         'veritatis quo atque autem totam. Odio quaerat '
#                         'provident incidunt corrupti dolore.'},
#                {'_id': '573a13faf29313caabdeb9e7-Brienne of Tarth-229879730.0',
#                 'date': datetime.datetime(1977, 4, 14, 10, 28, 50),
#                 'email': 'gwendoline_christie@gameofthron.es',
#                 'movie_id': ObjectId('573a13faf29313caabdeb9e7'),
#                 'name': 'Brienne of Tarth',
#                 'text': 'Iure magnam illum nihil nam quidem. Similique non '
#                         'ipsum aliquid veritatis pariatur. Neque consequuntur '
#                         'doloremque quo totam vitae.'}]},
#  {'_id': ObjectId('573a13fbf29313caabdee1cc'),
#   'comments': [{'_id': '573a13fbf29313caabdee1cc-Samwell Tarly-230241518.0',
#                 'date': datetime.datetime(1977, 4, 18, 14, 58, 38),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a13fbf29313caabdee1cc'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Eos quibusdam ipsa quae libero quisquam. Deleniti '
#                         'ratione minus iusto quis adipisci nisi. Eveniet nihil '
#                         'nisi illum alias aliquid tempore.'}]}]

# %%
movie = movies.find(query, projection).skip(1).limit(1)

pprint.pprint(list(movie))
# Out:
# [{'_id': ObjectId('573a1391f29313caabcd8f9a'),
#   'comments': [{'_id': '573a1391f29313caabcd8f9a-Kelsey Smith-1367246967.0',
#                 'date': datetime.datetime(2013, 4, 29, 10, 49, 27),
#                 'email': 'kelsey_smith@fakegmail.com',
#                 'movie_id': ObjectId('573a1391f29313caabcd8f9a'),
#                 'name': 'Kelsey Smith',
#                 'text': 'Modi minima necessitatibus beatae deleniti suscipit '
#                         'rerum. Nulla blanditiis officiis sed at vel repellat '
#                         'sequi. Fuga ipsam molestiae architecto nulla qui '
#                         'aut.'},
#                {'_id': '573a1391f29313caabcd8f9a-Samwell Tarly-961928262.0',
#                 'date': datetime.datetime(2000, 6, 25, 6, 17, 42),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1391f29313caabcd8f9a'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Incidunt placeat rem molestiae optio laborum. At '
#                         'necessitatibus impedit ratione iure voluptates nobis '
#                         'explicabo. In quae pariatur repellat nobis. '
#                         'Exercitationem ullam eveniet non.'},
#                {'_id': '573a1391f29313caabcd8f9a-Kristen Schmidt-489082166.0',
#                 'date': datetime.datetime(1985, 7, 1, 12, 9, 26),
#                 'email': 'kristen_schmidt@fakegmail.com',
#                 'movie_id': ObjectId('573a1391f29313caabcd8f9a'),
#                 'name': 'Kristen Schmidt',
#                 'text': 'Sit quam eos at eligendi quis ex ipsam. Ab alias cum '
#                         'ex ipsam. Reprehenderit harum incidunt iusto veniam '
#                         'omnis est.'}]}]

# %%
betterQuery = {
  "comments": {
    "$elemMatch": {
      "name": "Samwell Tarly",
      "date": {
        "$lt": dateparser.parse("1995-01-01")
      }
    }
  }
}

correctMovies = list(movies.find(betterQuery, projection).limit(2))

pprint.pprint(correctMovies)
# Out:
# [{'_id': ObjectId('573a1390f29313caabcd54ed'),
#   'comments': [{'_id': '573a1390f29313caabcd54ed-Tywin Lannister-1337423784.0',
#                 'date': datetime.datetime(2012, 5, 19, 6, 36, 24),
#                 'email': 'charles_dance@gameofthron.es',
#                 'movie_id': ObjectId('573a1390f29313caabcd54ed'),
#                 'name': 'Tywin Lannister',
#                 'text': 'Sapiente tempora non vero officiis assumenda '
#                         'eligendi. Consequatur iusto qui in possimus animi '
#                         'modi. Id commodi non ipsam. Ad officia nisi dolor '
#                         'voluptatibus numquam porro ducimus.'},
#                {'_id': '573a1390f29313caabcd54ed-Samwell Tarly-572777793.0',
#                 'date': datetime.datetime(1988, 2, 25, 3, 56, 33),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1390f29313caabcd54ed'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Natus enim voluptate dolore. Quo porro ipsum enim. '
#                         'Est totam sapiente nam vero.'},
#                {'_id': '573a1390f29313caabcd54ed-Emily Ellis-557039795.0',
#                 'date': datetime.datetime(1987, 8, 27, 1, 16, 35),
#                 'email': 'emily_ellis@fakegmail.com',
#                 'movie_id': ObjectId('573a1390f29313caabcd54ed'),
#                 'name': 'Emily Ellis',
#                 'text': 'Facere magnam quibusdam impedit sed expedita neque. '
#                         'Eos rem minus blanditiis non id quibusdam quia. Nam '
#                         'harum nam iure voluptatem doloribus quis ut incidunt. '
#                         'Maxime accusamus veniam ut quas ipsam.'}]},
#  {'_id': ObjectId('573a1391f29313caabcd91dc'),
#   'comments': [{'_id': '573a1391f29313caabcd91dc-Patricia Good-1254693496.0',
#                 'date': datetime.datetime(2009, 10, 4, 17, 58, 16),
#                 'email': 'patricia_good@fakegmail.com',
#                 'movie_id': ObjectId('573a1391f29313caabcd91dc'),
#                 'name': 'Patricia Good',
#                 'text': 'Laudantium sed amet sed sint blanditiis facilis. '
#                         'Alias omnis sequi pariatur voluptates repudiandae '
#                         'dicta. Dignissimos natus corporis voluptatum impedit '
#                         'commodi.'},
#                {'_id': '573a1391f29313caabcd91dc-Samwell Tarly-766239623.0',
#                 'date': datetime.datetime(1994, 4, 13, 8, 20, 23),
#                 'email': 'john_bradley-west@gameofthron.es',
#                 'movie_id': ObjectId('573a1391f29313caabcd91dc'),
#                 'name': 'Samwell Tarly',
#                 'text': 'Alias qui voluptate facilis id. Odit ducimus nulla '
#                         'excepturi. Veniam quam voluptatem recusandae vitae '
#                         'perspiciatis. Inventore ad laborum amet magnam '
#                         'voluptatum.'},
#                {'_id': '573a1391f29313caabcd91dc-Megan Richards-345323060.0',
#                 'date': datetime.datetime(1980, 12, 10, 14, 4, 20),
#                 'email': 'megan_richards@fakegmail.com',
#                 'movie_id': ObjectId('573a1391f29313caabcd91dc'),
#                 'name': 'Megan Richards',
#                 'text': 'Nisi rerum quasi nemo eaque incidunt optio nisi. '
#                         'Eveniet delectus ex iure vero cum quae nisi. Numquam '
#                         'repudiandae similique doloremque.'}]}]
